# %%
import numpy as np
import pandas as pd
import urllib.request
import bs4
import re
import time

from google import search

# %%
df = pd.read_csv('../../result/final.annotations.txt', sep='\t')
grouped = df.groupby('pdb_id')

# %%
df.head()
# Out:
#   pdb_id      species chain_mhc_a mhc_a_allele chain_mhc_b mhc_b_allele  \
# 0   2f53  HomoSapiens           A   A*02:01:48           B          B2M
# 1   2f53  HomoSapiens           A   A*02:01:48           B          B2M
# 2   2f53  HomoSapiens           A   A*02:01:48           B          B2M
# 3   2f53  HomoSapiens           A   A*02:01:48           B          B2M
# 4   2f53  HomoSapiens           A   A*02:01:48           B          B2M
#
#   mhc_type chain_antigen antigen_seq chain_tcr tcr_v_allele tcr_j_allele  \
# 0     MHCI             C   SLLMWITQC         D    TRAV21*01          NaN
# 1     MHCI             C   SLLMWITQC         D    TRAV21*01          NaN
# 2     MHCI             C   SLLMWITQC         D    TRAV21*01          NaN
# 3     MHCI             C   SLLMWITQC         E   TRBV6-5*01          NaN
# 4     MHCI             C   SLLMWITQC         E   TRBV6-5*01          NaN
#
#   tcr_region  tcr_region_start  tcr_region_end   tcr_region_seq
# 0       CDR1                27              33           DSAIYN
# 1       CDR2                50              53              IPF
# 2       CDR3                90             105  CAVRPTSGGSYIPTF
# 3       CDR1                24              31          QDMNHEY
# 4       CDR2                48              51              SVS

# %%
columns = ['chunk.id', 'cdr3.alpha', 'v.alpha', 'j.alpha', 'cdr3.beta', 'v.beta',
       'd.beta', 'j.beta', 'species', 'mhc.a', 'mhc.b', 'mhc.class',
       'antigen.epitope', 'antigen.gene', 'antigen.species', 'reference.id',
       'method.identification', 'method.frequency', 'method.singlecell',
       'method.sequencing', 'method.verification', 'meta.study.id',
       'meta.cell.subset', 'meta.subset.frequency', 'meta.subject.cohort',
       'meta.subject.id', 'meta.replica.id', 'meta.clone.id',
       'meta.epitope.id', 'meta.tissue', 'meta.donor.MHC',
       'meta.donor.MHC.method', 'meta.structure.id']

# %%
# in grouped.groups.keys()

# %%
rows = []
for key, group in grouped:
    row = pd.Series([np.nan]*len(columns), columns)
    row['chunk.id'] = key
    row['cdr3.alpha'] = group.loc[(group.tcr_v_allele.str.startswith('TRA')) & 
                                  (group.tcr_region == 'CDR3'), 'tcr_region_seq'].iloc[0]
    row['v.alpha'] = group.loc[(group.tcr_v_allele.str.startswith('TRA')), 'tcr_v_allele'].iloc[0]
    row['j.alpha'] = group.loc[(group.tcr_v_allele.str.startswith('TRA')), 'tcr_j_allele'].iloc[0]
    row['cdr3.beta'] = group.loc[(group.tcr_v_allele.str.startswith('TRB')) & 
                                 (group.tcr_region == 'CDR3'), 'tcr_region_seq'].iloc[0]
    row['v.beta'] = group.loc[(group.tcr_v_allele.str.startswith('TRB')), 'tcr_v_allele'].iloc[0]
    row['j.beta'] = group.loc[(group.tcr_v_allele.str.startswith('TRB')), 'tcr_j_allele'].iloc[0]
    row['species'] = group['species'].iloc[0]
    row['mhc.a'] = group['mhc_a_allele'].iloc[0]
    row['mhc.b'] = group['mhc_b_allele'].iloc[0]
    row['mhc.class'] = group['mhc_type'].iloc[0]
    row['antigen.epitope'] = group['antigen_seq'].iloc[0]
    row['mhc.class'] = group['mhc_type'].iloc[0]
    rows.append(row)    
    
db = pd.concat(rows, axis=1).T

# Somehow id '4e41' transformed into float 4e+41
ind = db['chunk.id'].apply(type) == float
if any(ind):
    db.loc[ind, 'chunk.id'] = '4e41'

# %%
db.head()
# Out:
#   chunk.id        cdr3.alpha        v.alpha j.alpha         cdr3.beta  \
# 0     1ao7     CAVTTDSWGKLQF    TRAV12-2*02       .  CASRPGLAGGRPEQYF
# 1     1bd2      CAAMEGAQKLVF  TRAV29_DV5*01       .   CASSYPGGGFYEQYF
# 2     1d9k      CAATGSFNKLTF   TRAV14D-2*01       .     CASGGQGRAEQFF
# 3     1fo0  CAMRGDYGGSGNKLIF      TRAV16*01       .      CSADRVGNTLYF
# 4     1fyt   CAVSESPFGNEKLTF     TRAV8-4*01       .    CASSSTGLPYGYTF
#
#         v.beta d.beta      j.beta      species         mhc.a  \
# 0   TRBV6-5*01    NaN  TRBJ2-3*01  HomoSapiens    A*02:01:59
# 1   TRBV6-5*01    NaN  TRBJ2-3*01  HomoSapiens    A*02:01:48
# 2  TRBV13-2*03    NaN  TRBJ2-5*01  MusMusculus       2944427
# 3     TRBV1*01    NaN           .  MusMusculus      48425589
# 4    TRBV28*01    NaN           .  HomoSapiens  DRA*01:02:03
#
#          ...        meta.subset.frequency meta.subject.cohort meta.subject.id  \
# 0        ...                          NaN                 NaN             NaN
# 1        ...                          NaN                 NaN             NaN
# 2        ...                          NaN                 NaN             NaN
# 3        ...                          NaN                 NaN             NaN
# 4        ...                          NaN                 NaN             NaN
#
#   meta.replica.id meta.clone.id meta.epitope.id meta.tissue meta.donor.MHC  \
# 0             NaN           NaN             NaN         NaN            NaN
# 1             NaN           NaN             NaN         NaN            NaN
# 2             NaN           NaN             NaN         NaN            NaN
# 3             NaN           NaN             NaN         NaN            NaN
# 4             NaN           NaN             NaN         NaN            NaN
#
#   meta.donor.MHC.method meta.structure.id
# 0                   NaN               NaN
# 1                   NaN               NaN
# 2                   NaN               NaN
# 3                   NaN               NaN
# 4                   NaN               NaN
#
# [5 rows x 33 columns]

# %%
def get_pubmed_id(pdb_id):
    try:
        url = 'http://www.rcsb.org/pdb/explore.do?structureId='+pdb_id.lower()
        source = urllib.request.urlopen(url).read()
        soup = bs4.BeautifulSoup(source, 'html5lib')
        string = str(soup.find('meta', {'name':'description'}))
        pattern = re.compile('<meta content="[0-9A-Za-z]{4}:\s+(.+)" name')
        article = pattern.match(string).group(1)
    except BaseException:
        print(pdb_id.lower()+': '+"Something's wrong")
        return np.nan
    for counter in range(1):
        try:
            if counter > 0:
                time.sleep(np.random.random_integers(10, 30))
            links = [url for url in search(article, stop=40)]
            pmids = [split[-1] if split[-2] == 'pubmed' else '' for split in [link.split('/') for link in links]]
            global pm
            pm = pmids[np.where(np.array(pmids) != '')[0][0]]
        except BaseException as e:
            if str(e).find('503'):
                raise Exception('Seems google blocked you')
            continue
        else:
            break
    print(pdb_id.lower()+': '+pm)
    return pm

# %%
#refs = pd.Series([get_pubmed_id(pdb_id) for pdb_id in db['chunk.id']], list(db['chunk.id']))

# %%
#get_pubmed_id('1ao7')

# %%
#refs = refs.apply(lambda x: 'PMID'+x)
#db['reference.id'] = refs
#db.to_csv('database.txt', sep='\t', index=False)

# %%
def get_pubmed_id2(pdb_id):
    try:
        url = 'http://www.rcsb.org/pdb/explore.do?structureId='+pdb_id
        source = urllib.request.urlopen(url).read()
        soup = bs4.BeautifulSoup(source, 'html5lib')
        string = str(soup.find('meta', {'name':'description'}))
        pattern = re.compile('<meta content="[0-9A-Za-z]{4}:\s+(.+)" name')
        article = pattern.match(string).group(1)

        mkquery = lambda x: 'http://www.ncbi.nlm.nih.gov/pubmed?term=%28'+'+'.join(x.split(' '))+'[Title]%29'
        url = mkquery(article)
        print('Article url: '+url)
        source = urllib.request.urlopen(url).read()
        soup = bs4.BeautifulSoup(source, 'html.parser')
        if any(np.array([x.text for x in soup.findAll('h3')]) == 'Abstract'):
            find_pmid = lambda x: x.findAll('div', id='maincontent')[0].findAll('div', 'resc')[0].find('dd').text
            res = find_pmid(soup)
            print('PMID: '+res+'\n')
            return res
        if any(np.array([x.text for x in soup.findAll('h2')]) == 'Search results'):
            find_pmid = lambda x: x.findAll('div', id='maincontent')[0].findAll('dl', 'rprtid')[0].find('dd').text
            res = find_pmid(soup)+'?'
            print('PMID: '+res+'\n')
            return res
        print('PMID: not found\n')
        return ''
    except BaseException:
        return ''

# %%
refs = pd.Series([get_pubmed_id2(pdb_id) for pdb_id in db['chunk.id']], list(db['chunk.id']))
# Out:
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structure+of+the+complex+between+human+T-cell+receptor,+viral+peptide+and+HLA-A2.[Title]%29
# PMID: 21084668?
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28The+crystal+structure+of+a+T+cell+receptor+in+complex+with+peptide+and+MHC+class+II.[Title]%29
# PMID: 10583947
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Crystal+structure+of+a+T+cell+receptor+bound+to+an+allogeneic+MHC+molecule.[Title]%29
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28A+functional+hot+spot+for+antigen+recognition+in+a+superagonist+TCR/MHC+complex.[Title]%29
# PMID: 10755612
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structure+of+a+complex+of+the+human+alpha/beta+T+cell+receptor+(TCR)+HA1.7,+influenza+hemagglutinin+peptide,+and+major+histocompatibility+complex+class+II+molecule,+HLA-DR4+(DRA*0101+and+DRB1*0401):+insight+into+TCR+cross-restriction+and+alloreactivity.[Title]%29
# PMID: 11877480
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28A+T+cell+receptor+CDR3beta+loop+undergoes+conformational+changes+of+unprecedented+magnitude+upon+binding+to+a+peptide/MHC+class+I+complex.[Title]%29
# PMID: 11911820
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28A+Structural+Basis+for+the+Selection+of+Dominant+alphabeta+T+Cell+Receptors+in+Antiviral+Immunity[Title]%29
# PMID: 12530975
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structural+comparison+of+allogeneic+and+syngeneic+T+cell+receptor-peptide-major+histocompatibility+complex+complexes:+a+buried+alloreactive+mutation+subtly+alters+peptide+presentation+substantially+increasing+V(beta)+Interactions.[Title]%29
# PMID: 11994422
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28CDR3+loop+flexibility+contributes+to+the+degeneracy+of+TCR+recognition[Title]%29
# PMID: 12563259
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28A+Structural+Basis+for+Immunodominant+Human+T+Cell+Receptor+Recognition[Title]%29
# PMID: 22343629?
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Four+A6-TCR/peptide/HLA-A2+structures+that+generate+very+different+T+cell+signals+are+nearly+identical.[Title]%29
# PMID: 10435578
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Four+A6-TCR/peptide/HLA-A2+structures+that+generate+very+different+T+cell+signals+are+nearly+identical.[Title]%29
# PMID: 10435578
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Four+A6-TCR/peptide/HLA-A2+structures+that+generate+very+different+T+cell+signals+are+nearly+identical.[Title]%29
# PMID: 10435578
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structure+of+an+autoimmune+T+cell+receptor+complexed+with+class+II+peptide-MHC:+insights+into+MHC+bias+and+antigen+specificity[Title]%29
# PMID: 15664161
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structure+of+a+human+autoimmune+TCR+bound+to+a+myelin+basic+protein+self-peptide+and+a+multiple+sclerosis-associated+MHC+class+II+molecule.[Title]%29
# PMID: 16079912
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28T+cell+receptor+recognition+of+a+'super-bulged'+major+histocompatibility+complex+class+I-bound+peptide[Title]%29
# PMID: 16186824
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structural+and+Kinetic+Basis+for+Heightened+Immunogenicity+of+T+Cell+Vaccines[Title]%29
# PMID: 15837811
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structural+and+Kinetic+Basis+for+Heightened+Immunogenicity+of+T+Cell+Vaccines[Title]%29
# PMID: 15837811
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structural+basis+of+plasticity+in+T+cell+receptor+recognition+of+a+self+peptide-MHC+antigen.[Title]%29
# PMID: 9469799
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structural+basis+for+a+major+histocompatibility+complex+class+Ib-restricted+T+cell+response[Title]%29
# PMID: 16474394
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Directed+evolution+of+human+T+cell+receptor+CDR2+residues+by+phage+display+dramatically+enhances+affinity+for+cognate+peptide-MHC+without+increasing+apparent+cross-reactivity.[Title]%29
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Directed+evolution+of+human+T+cell+receptor+CDR2+residues+by+phage+display+dramatically+enhances+affinity+for+cognate+peptide-MHC+without+increasing+apparent+cross-reactivity.[Title]%29
# PMID: 16600963
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28T+Cell+Receptor+Recognition+via+Cooperative+Conformational+Plasticity.[Title]%29
# PMID: 16962135
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structural+basis+for+the+recognition+of+mutant+self+by+a+tumor-specific,+MHC+class+II-restricted+T+cell+receptor[Title]%29
# PMID: 17334368
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structural+basis+for+the+recognition+of+mutant+self+by+a+tumor-specific,+MHC+class+II-restricted+T+cell+receptor[Title]%29
# PMID: 17334368
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28A+T+cell+receptor+flattens+a+bulged+antigenic+peptide+presented+by+a+major+histocompatibility+complex+class+I+molecule[Title]%29
# PMID: 17259989
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28How+much+can+a+T-cell+antigen+receptor+adapt+to+structurally+distinct+antigenic+peptides?[Title]%29
# PMID: 17363906
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Crystal+structures+of+high+affinity+human+T-cell+receptors+bound+to+peptide+major++histocompatibility+complex+reveal+native+diagonal+binding+geometry[Title]%29
# PMID: 17644531
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Crystal+structures+of+high+affinity+human+T-cell+receptors+bound+to+peptide+major++histocompatibility+complex+reveal+native+diagonal+binding+geometry[Title]%29
# PMID: 17644531
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structural+evidence+for+a+germline-encoded+T+cell+receptor-major+histocompatibility+complex+interaction+'codon'.[Title]%29
# PMID: 17694060
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Crystal+structures+of+high+affinity+human+T-cell+receptors+bound+to+peptide+major++histocompatibility+complex+reveal+native+diagonal+binding+geometry[Title]%29
# PMID: 17644531
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28The+Structural+Dynamics+and+Energetics+of+an+Immunodominant+T-Cell+Receptor+are+Programmed+by+its+Vbeta+Domain[Title]%29
# PMID: 18275829
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28The+Structural+Dynamics+and+Energetics+of+an+Immunodominant+T-Cell+Receptor+are+Programmed+by+its+Vbeta+Domain[Title]%29
# PMID: 18275829
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28The+Structural+Dynamics+and+Energetics+of+an+Immunodominant+T-Cell+Receptor+are+Programmed+by+its+Vbeta+Domain[Title]%29
# PMID: 18275829
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28The+Structure+of+Superantigen+Complexed+with+Tcr+and+Mhc+Reveals+Novel+Insights+Into+Superantigenic+T+Cell+Activation.[Title]%29
# PMID: 21081917
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structural+Features+Underlying+T-Cell+Receptor+Sensitivity+to+Concealed+Mhc+Class+I+Micropolymorphisms.[Title]%29
# PMID: 23161907
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structural+evidence+for+a+germline-encoded+T+cell+receptor-major+histocompatibility+complex+interaction+'codon'[Title]%29
# PMID: 17694060
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Fluorine+substitutions+in+an+antigenic+peptide+selectively+modulate+T-cell+receptor+binding+in+a+minimally+perturbing+manner[Title]%29
# PMID: 19698083
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Fluorine+substitutions+in+an+antigenic+peptide+selectively+modulate+T-cell+receptor+binding+in+a+minimally+perturbing+manner.[Title]%29
# PMID: 19698083
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Natural+micropolymorphism+in+human+leukocyte+antigens+provides+a+basis+for+genetic+control+of+antigen+recognition.[Title]%29
# PMID: 19139173
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28The+shaping+of+T+cell+receptor+recognition+by+self-tolerance.[Title]%29
# PMID: 19167249
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structural+bases+for+the+affinity-driven+selection+of+a+public+TCR+against+a+dominant+human+cytomegalovirus+epitope.[Title]%29
# PMID: 19542454
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28T+cell+receptor+cross-reactivity+directed+by+antigen-dependent+tuning+of+peptide-MHC+molecular+flexibility.[Title]%29
# PMID: 20064447
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Germ+line-governed+recognition+of+a+cancer+epitope+by+an+immunodominant+human+T-cell+receptor.[Title]%29
# PMID: 19605354
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28T+cell+allorecognition+via+molecular+mimicry.[Title]%29
# PMID: 20064448
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28T+cell+allorecognition+via+molecular+mimicry.[Title]%29
# PMID: 20064448
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Hard+wiring+of+T+cell+receptor+specificity+for+the+major+histocompatibility+complex+is+underpinned+by+TCR+adaptability[Title]%29
# PMID: 20483993
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28The+diabetogenic+mouse+MHC+class+II+molecule+I-Ag7+is+endowed+with+a+switch+that+modulates+TCR+affinity.[Title]%29
# PMID: 20407212
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Allelic+polymorphism+in+the+T+cell+receptor+and+its+impact+on+immune+responses[Title]%29
# PMID: 20566715
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Allelic+polymorphism+in+the+T+cell+receptor+and+its+impact+on+immune+responses[Title]%29
# PMID: 20566715
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Allelic+polymorphism+in+the+T+cell+receptor+and+its+impact+on+immune+responses[Title]%29
# PMID: 20566715
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Genetic+and+structural+basis+for+selection+of+a+ubiquitous+T+cell+receptor+deployed+in+Epstein-Barr+virus+infection.[Title]%29
# PMID: 21124993
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structural+basis+for+enabling+T-cell+receptor+diversity+within+biased+virus-specific+CD8++T-cell+responses[Title]%29
# PMID: 21606376
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Conformational+Melding+Permits+a+Conserved+Binding+Geometry+in+TCR+Recognition+of+Foreign+and+Self+Molecular+Mimics.[Title]%29
# PMID: 21282516
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28TCRs+Used+in+Cancer+Gene+Therapy+Cross-React+with+MART-1/Melan-A+Tumor+Antigens+via+Distinct+Mechanisms.[Title]%29
# PMID: 21795600
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28TCRs+Used+in+Cancer+Gene+Therapy+Cross-React+with+MART-1/Melan-A+Tumor+Antigens+via+Distinct+Mechanisms.[Title]%29
# PMID: 21795600
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28TCRs+Used+in+Cancer+Gene+Therapy+Cross-React+with+MART-1/Melan-A+Tumor+Antigens+via+Distinct+Mechanisms.[Title]%29
# PMID: 21795600
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28TCRs+Used+in+Cancer+Gene+Therapy+Cross-React+with+MART-1/Melan-A+Tumor+Antigens+via+Distinct+Mechanisms.[Title]%29
# PMID: 21795600
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Disparate+degrees+of+hypervariable+loop+flexibility+control+T-cell+receptor+cross-reactivity,+specificity,+and+binding+mechanism.[Title]%29
# PMID: 22019736
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structural+basis+of+specificity+and+cross-reactivity+in+T+cell+receptors+specific+for+cytochrome+c-I-E(k).[Title]%29
# PMID: 21490152
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28A+Single+T+Cell+Receptor+Bound+to+Major+Histocompatibility+Complex+Class+I+and+Class+II+Glycoproteins+Reveals+Switchable+TCR+Conformers.[Title]%29
# PMID: 21683626
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28A+structural+basis+for+varied+alpha-beta+TCR+usage+against+an+immunodominant++EBV+antigen+restricted++to+a+HLA-B8+molecule.[Title]%29
# PMID: 22140258
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structural+basis+for+the+killing+of+human+beta+cells+by+CD8(+)+T+cells+in+type+1+diabetes.[Title]%29
# PMID: 22245737
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structural+basis+for+the+killing+of+human+beta+cells+by+CD8(+)+T+cells+in+type+1+diabetes.[Title]%29
# PMID: 22245737
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structure+of+TCR+and+antigen+complexes+at+an+immunodominant+CTL+epitope+in+HIV-1+infection[Title]%29
# PMID: 24192765
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structure+of+TCR+and+antigen+complexes+at+an+immunodominant+CTL+epitope+in+HIV-1+infection[Title]%29
# PMID: 24192765
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structure+of+TCR+and+antigen+complexes+at+an+immunodominant+CTL+epitope+in+HIV-1+infection[Title]%29
# PMID: 24192765
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structure+of+the+Superantigen+Staphylococcal+Enterotoxin+B+in+Complex+with+Tcr+and+Peptide-Mhc+Demonstrates+Absence+of+Tcr-Peptide+Contacts.[Title]%29
# PMID: 25015819
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structural+description+of+how+different+MART-1+antigenic+peptides+influence+JKF6+T+cell+receptor+recognition[Title]%29
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structure+of+a+high+affinity+TCR+reveals+native+binding+to+MHC+with+enhanced+peptide+specificity[Title]%29
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28A+Molecular+Basis+for+the+Control+of+Preimmune+Escape+Variants+by+HIV-Specific+CD8(+)+T+Cells.[Title]%29
# PMID: 23521884
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28A+Molecular+Basis+for+the+Control+of+Preimmune+Escape+Variants+by+HIV-Specific+CD8(+)+T+Cells.[Title]%29
# PMID: 23521884
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Biased+T+Cell+Receptor+Usage+Directed+against+Human+Leukocyte+Antigen+DQ8-Restricted+Gliadin+Peptides+Is+Associated+with+Celiac+Disease[Title]%29
# PMID: 23063329
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28T-cell+receptor+specificity+maintained+by+altered+thermodynamics.[Title]%29
# PMID: 23698002
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28T-cell+receptor+specificity+maintained+by+altered+thermodynamics.[Title]%29
# PMID: 23698002
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28T-cell+receptor+specificity+maintained+by+altered+thermodynamics.[Title]%29
# PMID: 23698002
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Highly+divergent+T-cell+receptor+binding+modes+underlie+specific+recognition+of+a+bulged+viral+peptide+bound+to+a+human+leukocyte+antigen+class+I+molecule.[Title]%29
# PMID: 23569211
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Highly+divergent+T-cell+receptor+binding+modes+underlie+specific+recognition+of+a+bulged+viral+peptide+bound+to+a+human+leukocyte+antigen+class+I+molecule.[Title]%29
# PMID: 23569211
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Computational+design+of+the+affinity+and+specificity+of+a+therapeutic+T+cell+receptor.[Title]%29
# PMID: 24550723
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Molecular+basis+of+a+dominant+T+cell+response+to+an+HIV+reverse+transcriptase+8-mer+epitope+presented+by+the+protective+allele+HLA-B*51:01[Title]%29
# PMID: 24600035
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28T-cell+receptor+(TCR)-peptide+specificity+overrides+affinity-enhancing+TCR-major+histocompatibility+complex+interactions.[Title]%29
# PMID: 24196962
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28T-cell+receptor+recognition+of+HLA-DQ2-gliadin+complexes+associated+with+celiac+disease.[Title]%29
# PMID: 24777060
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28T-cell+receptor+recognition+of+HLA-DQ2-gliadin+complexes+associated+with+celiac+disease.[Title]%29
# PMID: 24777060
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28T-cell+receptor+recognition+of+HLA-DQ2-gliadin+complexes+associated+with+celiac+disease.[Title]%29
# PMID: 24777060
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28T-cell+receptor+recognition+of+HLA-DQ2-gliadin+complexes+associated+with+celiac+disease.[Title]%29
# PMID: 24777060
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Deconstructing+the+Peptide-MHC+Specificity+of+T+Cell+Recognition.[Title]%29
# PMID: 24855945
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Deconstructing+the+Peptide-MHC+Specificity+of+T+Cell+Recognition.[Title]%29
# PMID: 24855945
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Deconstructing+the+Peptide-MHC+Specificity+of+T+Cell+Recognition.[Title]%29
# PMID: 24855945
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28A+Molecular+Basis+for+the+Interplay+between+T+Cells,+Viral+Mutants,+and+Human+Leukocyte+Antigen+Micropolymorphism.[Title]%29
# PMID: 24759101
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28A+Molecular+Basis+for+the+Interplay+between+T+Cells,+Viral+Mutants,+and+Human+Leukocyte+Antigen+Micropolymorphism.[Title]%29
# PMID: 24759101
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28A+Molecular+Basis+for+the+Interplay+between+T+Cells,+Viral+Mutants,+and+Human+Leukocyte+Antigen+Micropolymorphism.[Title]%29
# PMID: 24759101
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Structural+basis+for+ineffective+T-cell+responses+to+MHC+anchor+residue-improved+"+heteroclitic"="[Title]%29
# PMID: 25471691
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28An+Extensive+Antigenic+Footprint+Underpins+Immunodominant+TCR+Adaptability+against+a+Hypervariable+Viral+Determinant.[Title]%29
# PMID: 25355921
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28T+cell+receptor+reversed+polarity+recognition+of+a+self-antigen+major+histocompatibility+complex.[Title]%29
# PMID: 26437244
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28T+cell+receptor+reversed+polarity+recognition+of+a+self-antigen+major+histocompatibility+complex.[Title]%29
# PMID: 26437244
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Determinants+of+Gliadin-Specific+T+Cell+Selection+in+Celiac+Disease.[Title]%29
# PMID: 25948817
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Determinants+of+Gliadin-Specific+T+Cell+Selection+in+Celiac+Disease.[Title]%29
# PMID: 25948817
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Determinants+of+Gliadin-Specific+T+Cell+Selection+in+Celiac+Disease.[Title]%29
# PMID: 25948817
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Crystal+structure+of+TCR+C7+in+complex+with+HCMV+NLV+epitope+presented+by+HLA-A2[Title]%29
# http://www.ncbi.nlm.nih.gov/pubmed?term=%28Crystal+structure+of+TCR+C7+in+complex+with+HCMV+NLV+epitope+presented+by+HLA-A2[Title]%29

# %%
print('Filling missed values')

# %%
refs[refs == '']
# Out:
# 4eup
# 4ftv
# dtype: object

# %%
refs['1bd2'] = '9586631'
refs['1fo0'] = '11017099'
refs['1fyt'] = '11060013'
refs['2f53'] = '16600963'
refs['2f54'] = '16600963'
refs['3d39'] = '19698083'
refs['4eup'] = ''
refs['4ftv'] = ''
refs['4e41'] = '17334368'
refs['5d2l'] = '26429912'
refs['5d2n'] = '26429912'

# %%
refs[refs.apply(lambda x: x[-1] == '?' if x else False)]
# Out:
# Series([], dtype: object)

# %%
refs['1ao7'] = '8906788'
refs['1oga'] = '12796775'

# %%
pretty_refs = refs.apply(lambda x: 'PMID:'+str(x))

# %%
db.index = db['chunk.id']
db.loc[:, 'reference.id'] = pretty_refs
db.to_csv('../../result/database.txt', sep='\t', index=False)
